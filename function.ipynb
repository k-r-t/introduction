# %% [markdown]
# 1.  **Functions:**
#     *   What they are and why we use them.
#     *   Defining your own functions (`def`).
#     *   Passing information *into* functions (Parameters and Arguments).
#     *   Getting results *back* from functions (`return`).
# 2.  **Variable Scope:**
#     *   Where variables exist (Local vs. Global).
#     *   How long variables exist (Lifetime).
# 3.  **Lambda Functions:** A shortcut for creating simple, one-line functions.
#
# 4.  **Operations on String:** Operation that can be done with string
#
# # Benefits shown:
# - Reusability: The greeting logic and separator are written once in `greet_person`.
# - Readability: `greet_person("Alice")` clearly states the intent.
#
# **Syntax for Defining:**
#
# def function_name():  # Use 'def', choose a name, add parentheses (), and a colon :
#     # Indented block of code (the function's body)
#     # This code runs ONLY when the function is called
#     print("Hello from inside the function!")
#     # More code can go here...

# %%
def greet_person(a,b):
  print(f"Hello, {a}! ")

greet_person(b =2, a=4)
greet_person("Shyam","hari")  
greet_person("Sita",3)
# Out:
# Hello, 4!
# Hello, Shyam!
# Hello, Sita!

# %%
def greet_person(a,b):
    print(f"Hello, {a} and {b} !!")

greet_person("sita","ram")
# Out:
# Hello, sita and ram !!

# %%
def greet_person(name,surname):
    print(f"Hello, {name} {surname}.")

greet_person("riya","shakya")
# Out:
# Hello, riya shakya.

# %%
# 1. Define a simple function
def greet_user():
   
    print("Hello there, user!")
    print("Welcome to the world of functions.")

# --- Code outside the function ---
print("Program starting...")
# Out:
# Program starting...

# %%
greet_user()  #called the function so the line inside it is also printed
# Out:
# Hello there, user!
# Welcome to the world of functions.

# %%
def add(a,b):
    result=a+b
    result1=a-b

    return result, result1

# %%
add(2,3)
# Out:
# (5, -1)

# %%
add(4,2)
# Out:
# (6, 2)

# %%
x=3
y=2
add_result,sub_result=add(x,y)
print(add_result)
print(sub_result)
# Out:
# 5
# 1

# %% [markdown]
# def function_name(parameter1, parameter2, ...):
#
#     return value

# %%
def add_numbers(x,y,c):
    result = x + y +c
    print(f"The sum of {x}, {y} and {c} is: {result}")
    return result

add_numbers(2, 4,0)
# Out:
# The sum of 2, 4 and 0 is: 6
# 6

# %%
add_numbers(2,3,2)
# Out:
# The sum of 2, 3 and 2 is: 7
# 7

# %% [markdown]
# #fruitful functions
# ## functions that perform a specific task and return a value or result after their execution

# %%
def add(a,b):
   
    return a + b
   
x = int(input("Enter the first number:"))
y = int(input("Enter the second number:"))

result = add(x,y)
print(f"Result of {x} and {y}:  {result}")
# Out:
# Enter the first number: 1
# Enter the second number: 4
# Result of 1 and 4:  5

# %%
def show_args(*args):
    lists =""
    for item in args:
        print(item)
        lists += item
    return lists
    
value=show_args("1","2")   #must be in string to concatinate
print(value)
# Out:
# 1
# 2
# 12

# %%
def show_args(*args):
    global lists
    lists =0           # no string so can put in integer
    for item in args:
        print(item)
        lists += item
    return lists
    
value=show_args(1,2)
print(value)   # now it will be added not concatinated
print(list)   
print(lists) # If not global then error cuz it is a function
# Out:
# 1
# 2
# 3
# <class 'list'>
# 3

# %%
sum = 0
def addition(*args):
    for item in args:
        global sum
        sum = sum + item
    return sum

addition(1,2,4,22,44,55,55)
# Out:
# 183

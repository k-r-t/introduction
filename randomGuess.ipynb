# %%
import random
secret_number =random.randint(1, 20)

### run this code in separate cell 
### compare secret_number with your input number

# %%
answer= input("Enter any random number between 0 and 21:)
            if secret_number == random.randit:
                  print(f"You have guessed the correct random number! {randon.randit}")
            else:

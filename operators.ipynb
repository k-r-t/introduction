# %%
result=5>9
print(result)
# Out:
# False

# %%
a=15
b=4
print(f"a = {a}, b = {b}")
# Out:
# a = 15, b = 4

# %%
print(f"Subtraction (a - b): {a-b}") 
print(f"Multiplication (a * b):{a*b}")
# Out:
# Subtraction (a - b): 11
# Multiplication (a * b):60

# %%
print(f"Addition (a + b):{a+b}")
# Out:
# Addition (a + b):19

# %%
print(f"Division (a / b): {a / b}")           # Division (returns float)
print(f"Floor Division (a // b): {a // b}")   # Floor Division (returns integer)
print(f"Modulus (a % b): {a % b}")            # Modulus (remainder)
print(f"Exponentiation (a ** b): {a ** b}")    #power 15 power 4/ exponential
# Out:
# Division (a / b): 3.75
# Floor Division (a // b): 3
# Modulus (a % b): 3
# Exponentiation (a ** b): 50625

# %%
# Floor division vs regular division
print(f"10 / 3 = {10 / 3}")
print(f"10 // 3 = {10 // 3}")
# Out:
# 10 / 3 = 3.3333333333333335
# 10 // 3 = 3

# %%
# Modulus operator for remainder
print(f"17 % 5 = {17 % 5}")  

# Exponentiation
print(f"2 ** 3 = {2 ** 3}")  
print(f"5 ** 2 = {5 ** 2}")
# Out:
# 17 % 5 = 2
# 2 ** 3 = 8
# 5 ** 2 = 25

# %%
x=2
y=5
print(f"Less than (x<y):{x<y}")
print(f"greater than equal to (x>=y):{x>=y}")
# Out:
# Less than (x<y):True
# greater than equal to (x>=y):False

# %%
# Comparison operators
x = 8
y = 8

print(f"x = {x}, y = {y}")
print(f"Equal to (x == y): {x == y}")
print(f"Not equal to (x != y): {x != y}")
# Out:
# x = 8, y = 8
# Equal to (x == y): True
# Not equal to (x != y): False

# %%
# Practical examples
age = 25
voting_age = 18
speed = 75
speed_limit = 65
password = "python123"
entered_password = "python1123"

age= int(input("Enter age: "))

if (age >= 18):
    print(f"You are eligible to vote")
else:
    print(f"You are not eligible to vote.")
    
print(f"is speed greater than or equal to speed limit? :{speed>=speed_limit}")
print(f"is the password correct?: {password == entered_password}")
# Out:
# Enter age:  18
# You are eligible to vote
# is speed greater than or equal to speed limit? :True
# is the password correct?: False

# %%
result = (10 + 5) * 2 > 25
print(f"(10 + 5) * 2 > 25: {result}")
# Out:
# (10 + 5) * 2 > 25: True

# %%
# Comparing different data types
print(f"\n10 == 10.0: {10 == 10.0}")  
print(f"'hello' == 'Hello': {'hello' == 'Hello'}")
# Out:
# 10 == 10.0: True
# 'hello' == 'Hello': False

# %%
age = int(input("Enter the age"))
print(f"Age is : {age}")
if (age>=18):
    print("You are eligible to vote.")
elif (age==18):
    print("You are also eligible to vote.")
else:
    print("You are not eligible to vote.")
print("Program finished")
# Out:
# Enter the age 18
# Age is : 18
# You are eligible to vote.
# Program finished

# %%
# syntax
temp=15
print(f"Temperature is : {temp}")
if temp>25:
    print("It is a warm day.")
else:
    print("It is a chilly day.")

print("-"* 20)
# Out:
# Temperature is : 15
# It is a chilly day.
# --------------------

# %%
score = 85.5
print(f"Score is: {score}")

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")

print("-" * 20)
# Out:
# Score is: 85.5
# Grade: B
# --------------------

# %% [raw]
# #Conditions with logical operators (and, or, not)
# #AND
# | True | True | T |
# | True | False | F |
# | False | True | F |
# | False | False | F |
#
# #OR
# | True | True | T |
# | True | False | T |
# | False | True | T |
# | False | False | F |
#
# #NOT
# | True | False |
# | False | True |

# %%
# Example 4: Conditions with logical operators (and, or, not)
has_ticket = False
has_id = False
print(f"Has Ticket: {has_ticket}, Has ID: {has_id}")

if has_ticket and has_id:
    print("Entry allowed.")
elif has_ticket or has_id:
    print("Partial requirements met.Check with staff")
    if not has_id:
        print("Warning : ID is missing.")
else :
    print("Entry denied")
# Out:
# Has Ticket: False, Has ID: False
# Entry denied

# %%
swimming_dress=False
has_ticket= True
can_swim= True
print(f"Has swimming dress : {swimming_dress}, Has ticket = {has_ticket}, Can swim={can_swim}")
if swimming_dress and can_swim and has_ticket:
    print("Entry allowed.")
elif not has_ticket:
        print("Entry partially allowed. Get tickets.")
elif not swimming_dress:
    print("Buy/Get swimming dress to enter.")
else :
    print("Entry denied")
# Out:
# Has swimming dress : False, Has ticket = True, Can swim=True
# Buy/Get swimming dress to enter.

# %%
print(5//2)
# Out:
# 2

# %%
x = 10


x += 5


print(x)
# Out:
# 15

# %%
print(not (5 > 2))
# Out:
# False

# %%
age = 20


if age >= 18:


    status = "Adult"


else:


    status = "Minor"


print(status)
# Out:
# Adult

# %%
x = 7


if x % 2 == 0:


    print("Even")


else:


    print("Odd")
# Out:
# Odd

# %%
print(2 ** 3 ** 0)
# Out:
# 2

# %%
x = 15


if x < 10:


    print("Low")


elif x < 20:


    print("Medium")


else:


    print("High")
# Out:
# Medium
